# %%
class person:

    def __init__(self, idade, sexo, status, localX, localY):

        self.idade = idade
        self.sexo = sexo
        self.status = status
        self.x = localX
        self.y = localY

    def getX(self):
        return self.x

    def getY(self):
        return self.y
    
    def __str__(self):
        return "x=" + str(self.x) + ", y=" + str(self.y)


p = Point(3,4)
print(p.getX())
print(p.getY())

# %%
 def distance(x1, y1, x2, y2)
  return((x2 − x1)**2 + (y2 − y1)**2)
